# %% [markdown]
# # Exploratory Data Analysis
# ## Pharmacy Store in Pune
#
# **Generated on:** 2025-10-01 17:43:20
# **Data Source:** Google Places & Trends API via Apify

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import json
from datetime import datetime
import warnings
warnings.filterwarnings('ignore')

plt.style.use('default')
sns.set_palette("husl")
# %matplotlib inline

# %%
# Load research data
research_data = {
  "places_data": [
    {
      "name": "Pharmacy Place 1",
      "address": "263 Main Street, pune",
      "rating": 4.7,
      "user_ratings_total": 342,
      "priceLevel": 4,
      "types": [
        "beauty_salon",
        "hair_care",
        "spa"
      ],
      "latitude": 18.582868,
      "longitude": 73.888117,
      "open_now": true,
      "phone_number": "+91 9509151003"
    },
    {
      "name": "Pharmacy Place 2",
      "address": "528 Main Street, pune",
      "rating": 4.4,
      "user_ratings_total": 133,
      "priceLevel": 1,
      "types": [
        "beauty_salon",
        "hair_care",
        "spa"
      ],
      "latitude": 18.517232,
      "longitude": 73.784125,
      "open_now": true,
      "phone_number": "+91 9601444025"
    },
    {
      "name": "Pharmacy Place 3",
      "address": "775 Main Street, pune",
      "rating": 3.6,
      "user_ratings_total": 498,
      "priceLevel": 4,
      "types": [
        "beauty_salon",
        "hair_care",
        "spa"
      ],
      "latitude": 18.513761,
      "longitude": 73.748641,
      "open_now": true,
      "phone_number": "+91 8489498008"
    },
    {
      "name": "Pharmacy Place 4",
      "address": "623 Main Street, pune",
      "rating": 4.5,
      "user_ratings_total": 142,
      "priceLevel": 2,
      "types": [
        "beauty_salon",
        "hair_care",
        "spa"
      ],
      "latitude": 18.498191,
      "longitude": 73.751178,
      "open_now": true,
      "phone_number": "+91 7593694665"
    },
    {
      "name": "Pharmacy Place 5",
      "address": "46 Main Street, pune",
      "rating": 3.9,
      "user_ratings_total": 418,
      "priceLevel": 2,
      "types": [
        "beauty_salon",
        "hair_care",
        "spa"
      ],
      "latitude": 18.524579,
      "longitude": 73.771894,
      "open_now": true,
      "phone_number": "+91 8659167674"
    },
    {
      "name": "Pharmacy Place 6",
      "address": "322 Main Street, pune",
      "rating": 4.3,
      "user_ratings_total": 278,
      "priceLevel": 4,
      "types": [
        "beauty_salon",
        "hair_care",
        "spa"
      ],
      "latitude": 18.575777,
      "longitude": 73.889242,
      "open_now": false,
      "phone_number": "+91 9272116880"
    },
    {
      "name": "Pharmacy Place 7",
      "address": "541 Main Street, pune",
      "rating": 4.5,
      "user_ratings_total": 409,
      "priceLevel": 1,
      "types": [
        "beauty_salon",
        "hair_care",
        "spa"
      ],
      "latitude": 18.471158,
      "longitude": 73.712634,
      "open_now": false,
      "phone_number": "+91 8155767707"
    },
    {
      "name": "Pharmacy Place 8",
      "address": "792 Main Street, pune",
      "rating": 4.0,
      "user_ratings_total": 235,
      "priceLevel": 2,
      "types": [
        "beauty_salon",
        "hair_care",
        "spa"
      ],
      "latitude": 18.412936,
      "longitude": 73.775282,
      "open_now": false,
      "phone_number": "+91 8796943592"
    },
    {
      "name": "Pharmacy Place 9",
      "address": "207 Main Street, pune",
      "rating": 4.1,
      "user_ratings_total": 491,
      "priceLevel": 1,
      "types": [
        "beauty_salon",
        "hair_care",
        "spa"
      ],
      "latitude": 18.409359,
      "longitude": 73.715934,
      "open_now": false,
      "phone_number": "+91 8333612367"
    },
    {
      "name": "Pharmacy Place 10",
      "address": "127 Main Street, pune",
      "rating": 3.8,
      "user_ratings_total": 272,
      "priceLevel": 2,
      "types": [
        "beauty_salon",
        "hair_care",
        "spa"
      ],
      "latitude": 18.45222,
      "longitude": 73.737148,
      "open_now": true,
      "phone_number": "+91 7311288561"
    },
    {
      "name": "Pharmacy Place 11",
      "address": "319 Main Street, pune",
      "rating": 4.7,
      "user_ratings_total": 279,
      "priceLevel": 3,
      "types": [
        "beauty_salon",
        "hair_care",
        "spa"
      ],
      "latitude": 18.57404,
      "longitude": 73.855252,
      "open_now": false,
      "phone_number": "+91 7642119772"
    },
    {
      "name": "Pharmacy Place 12",
      "address": "980 Main Street, pune",
      "rating": 3.7,
      "user_ratings_total": 367,
      "priceLevel": 1,
      "types": [
        "beauty_salon",
        "hair_care",
        "spa"
      ],
      "latitude": 18.463868,
      "longitude": 73.83362,
      "open_now": true,
      "phone_number": "+91 9896550099"
    },
    {
      "name": "Pharmacy Place 13",
      "address": "748 Main Street, pune",
      "rating": 4.3,
      "user_ratings_total": 232,
      "priceLevel": 1,
      "types": [
        "beauty_salon",
        "hair_care",
        "spa"
      ],
      "latitude": 18.460113,
      "longitude": 73.751076,
      "open_now": false,
      "phone_number": "+91 9802487914"
    },
    {
      "name": "Pharmacy Place 14",
      "address": "508 Main Street, pune",
      "rating": 3.9,
      "user_ratings_total": 486,
      "priceLevel": 2,
      "types": [
        "beauty_salon",
        "hair_care",
        "spa"
      ],
      "latitude": 18.501151,
      "longitude": 73.70998,
      "open_now": true,
      "phone_number": "+91 8567740342"
    },
    {
      "name": "Pharmacy Place 15",
      "address": "173 Main Street, pune",
      "rating": 3.9,
      "user_ratings_total": 72,
      "priceLevel": 1,
      "types": [
        "beauty_salon",
        "hair_care",
        "spa"
      ],
      "latitude": 18.512453,
      "longitude": 73.791642,
      "open_now": false,
      "phone_number": "+91 9645161967"
    },
    {
      "name": "Pharmacy Place 16",
      "address": "805 Main Street, pune",
      "rating": 4.3,
      "user_ratings_total": 473,
      "priceLevel": 1,
      "types": [
        "beauty_salon",
        "hair_care",
        "spa"
      ],
      "latitude": 18.448095,
      "longitude": 73.877633,
      "open_now": false,
      "phone_number": "+91 9517926129"
    },
    {
      "name": "Pharmacy Place 17",
      "address": "468 Main Street, pune",
      "rating": 4.3,
      "user_ratings_total": 69,
      "priceLevel": 1,
      "types": [
        "beauty_salon",
        "hair_care",
        "spa"
      ],
      "latitude": 18.596148,
      "longitude": 73.835017,
      "open_now": true,
      "phone_number": "+91 9640925893"
    },
    {
      "name": "Pharmacy Place 18",
      "address": "805 Main Street, pune",
      "rating": 3.7,
      "user_ratings_total": 86,
      "priceLevel": 4,
      "types": [
        "beauty_salon",
        "hair_care",
        "spa"
      ],
      "latitude": 18.476688,
      "longitude": 73.820857,
      "open_now": true,
      "phone_number": "+91 9647971723"
    },
    {
      "name": "Pharmacy Place 19",
      "address": "458 Main Street, pune",
      "rating": 4.1,
      "user_ratings_total": 351,
      "priceLevel": 4,
      "types": [
        "beauty_salon",
        "hair_care",
        "spa"
      ],
      "latitude": 18.474866,
      "longitude": 73.745086,
      "open_now": false,
      "phone_number": "+91 7595554231"
    },
    {
      "name": "Pharmacy Place 20",
      "address": "791 Main Street, pune",
      "rating": 4.4,
      "user_ratings_total": 358,
      "priceLevel": 2,
      "types": [
        "beauty_salon",
        "hair_care",
        "spa"
      ],
      "latitude": 18.557,
      "longitude": 73.700554,
      "open_now": false,
      "phone_number": "+91 9865481418"
    },
    {
      "name": "Pharmacy Place 21",
      "address": "1 Main Street, pune",
      "rating": 4.4,
      "user_ratings_total": 297,
      "priceLevel": 1,
      "types": [
        "beauty_salon",
        "hair_care",
        "spa"
      ],
      "latitude": 18.517112,
      "longitude": 73.850103,
      "open_now": true,
      "phone_number": "+91 8216832114"
    },
    {
      "name": "Pharmacy Place 22",
      "address": "721 Main Street, pune",
      "rating": 4.5,
      "user_ratings_total": 128,
      "priceLevel": 4,
      "types": [
        "beauty_salon",
        "hair_care",
        "spa"
      ],
      "latitude": 18.50981,
      "longitude": 73.881693,
      "open_now": false,
      "phone_number": "+91 8371890884"
    },
    {
      "name": "Pharmacy Place 23",
      "address": "153 Main Street, pune",
      "rating": 3.7,
      "user_ratings_total": 386,
      "priceLevel": 2,
      "types": [
        "beauty_salon",
        "hair_care",
        "spa"
      ],
      "latitude": 18.464648,
      "longitude": 73.801149,
      "open_now": true,
      "phone_number": "+91 7379588639"
    },
    {
      "name": "Pharmacy Place 24",
      "address": "548 Main Street, pune",
      "rating": 4.0,
      "user_ratings_total": 138,
      "priceLevel": 2,
      "types": [
        "beauty_salon",
        "hair_care",
        "spa"
      ],
      "latitude": 18.517319,
      "longitude": 73.765765,
      "open_now": false,
      "phone_number": "+91 8254661559"
    }
  ],
  "trends_data": [
    {
      "date": "2025-07-03",
      "value": 75,
      "query": "pharmacy store",
      "geo": "pune",
      "relatedQueries": [
        "pharmacy store near me",
        "best pharmacy store"
      ]
    },
    {
      "date": "2025-07-10",
      "value": 70,
      "query": "pharmacy store",
      "geo": "pune",
      "relatedQueries": [
        "pharmacy store near me",
        "best pharmacy store"
      ]
    },
    {
      "date": "2025-07-17",
      "value": 31,
      "query": "pharmacy store",
      "geo": "pune",
      "relatedQueries": [
        "pharmacy store near me",
        "best pharmacy store"
      ]
    },
    {
      "date": "2025-07-24",
      "value": 50,
      "query": "pharmacy store",
      "geo": "pune",
      "relatedQueries": [
        "pharmacy store near me",
        "best pharmacy store"
      ]
    },
    {
      "date": "2025-07-31",
      "value": 79,
      "query": "pharmacy store",
      "geo": "pune",
      "relatedQueries": [
        "pharmacy store near me",
        "best pharmacy store"
      ]
    },
    {
      "date": "2025-08-07",
      "value": 42,
      "query": "pharmacy store",
      "geo": "pune",
      "relatedQueries": [
        "pharmacy store near me",
        "best pharmacy store"
      ]
    },
    {
      "date": "2025-08-14",
      "value": 35,
      "query": "pharmacy store",
      "geo": "pune",
      "relatedQueries": [
        "pharmacy store near me",
        "best pharmacy store"
      ]
    },
    {
      "date": "2025-08-21",
      "value": 68,
      "query": "pharmacy store",
      "geo": "pune",
      "relatedQueries": [
        "pharmacy store near me",
        "best pharmacy store"
      ]
    },
    {
      "date": "2025-08-28",
      "value": 46,
      "query": "pharmacy store",
      "geo": "pune",
      "relatedQueries": [
        "pharmacy store near me",
        "best pharmacy store"
      ]
    },
    {
      "date": "2025-09-04",
      "value": 62,
      "query": "pharmacy store",
      "geo": "pune",
      "relatedQueries": [
        "pharmacy store near me",
        "best pharmacy store"
      ]
    },
    {
      "date": "2025-09-11",
      "value": 71,
      "query": "pharmacy store",
      "geo": "pune",
      "relatedQueries": [
        "pharmacy store near me",
        "best pharmacy store"
      ]
    },
    {
      "date": "2025-09-18",
      "value": 41,
      "query": "pharmacy store",
      "geo": "pune",
      "relatedQueries": [
        "pharmacy store near me",
        "best pharmacy store"
      ]
    }
  ],
  "metadata": {
    "business_type": "pharmacy store",
    "location": "pune",
    "timestamp": "20251001_174310",
    "data_quality": "high",
    "is_mock_data": false,
    "places_file": "data/raw/pharmacy_store_pune_20251001_174310_places.csv",
    "trends_file": "data/raw/pharmacy_store_pune_20251001_174310_trends.csv"
  },
  "api_data": true,
  "sampled_data": {
    "places": [
      {
        "name": "Pharmacy Place 1",
        "address": "263 Main Street, pune",
        "rating": 4.7,
        "user_ratings_total": 342,
        "priceLevel": 4,
        "types": [
          "beauty_salon",
          "hair_care",
          "spa"
        ],
        "latitude": 18.582868,
        "longitude": 73.888117,
        "open_now": true,
        "phone_number": "+91 9509151003"
      },
      {
        "name": "Pharmacy Place 2",
        "address": "528 Main Street, pune",
        "rating": 4.4,
        "user_ratings_total": 133,
        "priceLevel": 1,
        "types": [
          "beauty_salon",
          "hair_care",
          "spa"
        ],
        "latitude": 18.517232,
        "longitude": 73.784125,
        "open_now": true,
        "phone_number": "+91 9601444025"
      },
      {
        "name": "Pharmacy Place 3",
        "address": "775 Main Street, pune",
        "rating": 3.6,
        "user_ratings_total": 498,
        "priceLevel": 4,
        "types": [
          "beauty_salon",
          "hair_care",
          "spa"
        ],
        "latitude": 18.513761,
        "longitude": 73.748641,
        "open_now": true,
        "phone_number": "+91 8489498008"
      },
      {
        "name": "Pharmacy Place 4",
        "address": "623 Main Street, pune",
        "rating": 4.5,
        "user_ratings_total": 142,
        "priceLevel": 2,
        "types": [
          "beauty_salon",
          "hair_care",
          "spa"
        ],
        "latitude": 18.498191,
        "longitude": 73.751178,
        "open_now": true,
        "phone_number": "+91 7593694665"
      },
      {
        "name": "Pharmacy Place 5",
        "address": "46 Main Street, pune",
        "rating": 3.9,
        "user_ratings_total": 418,
        "priceLevel": 2,
        "types": [
          "beauty_salon",
          "hair_care",
          "spa"
        ],
        "latitude": 18.524579,
        "longitude": 73.771894,
        "open_now": true,
        "phone_number": "+91 8659167674"
      },
      {
        "name": "Pharmacy Place 6",
        "address": "322 Main Street, pune",
        "rating": 4.3,
        "user_ratings_total": 278,
        "priceLevel": 4,
        "types": [
          "beauty_salon",
          "hair_care",
          "spa"
        ],
        "latitude": 18.575777,
        "longitude": 73.889242,
        "open_now": false,
        "phone_number": "+91 9272116880"
      },
      {
        "name": "Pharmacy Place 7",
        "address": "541 Main Street, pune",
        "rating": 4.5,
        "user_ratings_total": 409,
        "priceLevel": 1,
        "types": [
          "beauty_salon",
          "hair_care",
          "spa"
        ],
        "latitude": 18.471158,
        "longitude": 73.712634,
        "open_now": false,
        "phone_number": "+91 8155767707"
      },
      {
        "name": "Pharmacy Place 8",
        "address": "792 Main Street, pune",
        "rating": 4.0,
        "user_ratings_total": 235,
        "priceLevel": 2,
        "types": [
          "beauty_salon",
          "hair_care",
          "spa"
        ],
        "latitude": 18.412936,
        "longitude": 73.775282,
        "open_now": false,
        "phone_number": "+91 8796943592"
      },
      {
        "name": "Pharmacy Place 9",
        "address": "207 Main Street, pune",
        "rating": 4.1,
        "user_ratings_total": 491,
        "priceLevel": 1,
        "types": [
          "beauty_salon",
          "hair_care",
          "spa"
        ],
        "latitude": 18.409359,
        "longitude": 73.715934,
        "open_now": false,
        "phone_number": "+91 8333612367"
      },
      {
        "name": "Pharmacy Place 10",
        "address": "127 Main Street, pune",
        "rating": 3.8,
        "user_ratings_total": 272,
        "priceLevel": 2,
        "types": [
          "beauty_salon",
          "hair_care",
          "spa"
        ],
        "latitude": 18.45222,
        "longitude": 73.737148,
        "open_now": true,
        "phone_number": "+91 7311288561"
      },
      {
        "name": "Pharmacy Place 11",
        "address": "319 Main Street, pune",
        "rating": 4.7,
        "user_ratings_total": 279,
        "priceLevel": 3,
        "types": [
          "beauty_salon",
          "hair_care",
          "spa"
        ],
        "latitude": 18.57404,
        "longitude": 73.855252,
        "open_now": false,
        "phone_number": "+91 7642119772"
      },
      {
        "name": "Pharmacy Place 12",
        "address": "980 Main Street, pune",
        "rating": 3.7,
        "user_ratings_total": 367,
        "priceLevel": 1,
        "types": [
          "beauty_salon",
          "hair_care",
          "spa"
        ],
        "latitude": 18.463868,
        "longitude": 73.83362,
        "open_now": true,
        "phone_number": "+91 9896550099"
      },
      {
        "name": "Pharmacy Place 13",
        "address": "748 Main Street, pune",
        "rating": 4.3,
        "user_ratings_total": 232,
        "priceLevel": 1,
        "types": [
          "beauty_salon",
          "hair_care",
          "spa"
        ],
        "latitude": 18.460113,
        "longitude": 73.751076,
        "open_now": false,
        "phone_number": "+91 9802487914"
      },
      {
        "name": "Pharmacy Place 14",
        "address": "508 Main Street, pune",
        "rating": 3.9,
        "user_ratings_total": 486,
        "priceLevel": 2,
        "types": [
          "beauty_salon",
          "hair_care",
          "spa"
        ],
        "latitude": 18.501151,
        "longitude": 73.70998,
        "open_now": true,
        "phone_number": "+91 8567740342"
      },
      {
        "name": "Pharmacy Place 15",
        "address": "173 Main Street, pune",
        "rating": 3.9,
        "user_ratings_total": 72,
        "priceLevel": 1,
        "types": [
          "beauty_salon",
          "hair_care",
          "spa"
        ],
        "latitude": 18.512453,
        "longitude": 73.791642,
        "open_now": false,
        "phone_number": "+91 9645161967"
      },
      {
        "name": "Pharmacy Place 16",
        "address": "805 Main Street, pune",
        "rating": 4.3,
        "user_ratings_total": 473,
        "priceLevel": 1,
        "types": [
          "beauty_salon",
          "hair_care",
          "spa"
        ],
        "latitude": 18.448095,
        "longitude": 73.877633,
        "open_now": false,
        "phone_number": "+91 9517926129"
      },
      {
        "name": "Pharmacy Place 17",
        "address": "468 Main Street, pune",
        "rating": 4.3,
        "user_ratings_total": 69,
        "priceLevel": 1,
        "types": [
          "beauty_salon",
          "hair_care",
          "spa"
        ],
        "latitude": 18.596148,
        "longitude": 73.835017,
        "open_now": true,
        "phone_number": "+91 9640925893"
      },
      {
        "name": "Pharmacy Place 18",
        "address": "805 Main Street, pune",
        "rating": 3.7,
        "user_ratings_total": 86,
        "priceLevel": 4,
        "types": [
          "beauty_salon",
          "hair_care",
          "spa"
        ],
        "latitude": 18.476688,
        "longitude": 73.820857,
        "open_now": true,
        "phone_number": "+91 9647971723"
      },
      {
        "name": "Pharmacy Place 19",
        "address": "458 Main Street, pune",
        "rating": 4.1,
        "user_ratings_total": 351,
        "priceLevel": 4,
        "types": [
          "beauty_salon",
          "hair_care",
          "spa"
        ],
        "latitude": 18.474866,
        "longitude": 73.745086,
        "open_now": false,
        "phone_number": "+91 7595554231"
      },
      {
        "name": "Pharmacy Place 20",
        "address": "791 Main Street, pune",
        "rating": 4.4,
        "user_ratings_total": 358,
        "priceLevel": 2,
        "types": [
          "beauty_salon",
          "hair_care",
          "spa"
        ],
        "latitude": 18.557,
        "longitude": 73.700554,
        "open_now": false,
        "phone_number": "+91 9865481418"
      },
      {
        "name": "Pharmacy Place 21",
        "address": "1 Main Street, pune",
        "rating": 4.4,
        "user_ratings_total": 297,
        "priceLevel": 1,
        "types": [
          "beauty_salon",
          "hair_care",
          "spa"
        ],
        "latitude": 18.517112,
        "longitude": 73.850103,
        "open_now": true,
        "phone_number": "+91 8216832114"
      },
      {
        "name": "Pharmacy Place 22",
        "address": "721 Main Street, pune",
        "rating": 4.5,
        "user_ratings_total": 128,
        "priceLevel": 4,
        "types": [
          "beauty_salon",
          "hair_care",
          "spa"
        ],
        "latitude": 18.50981,
        "longitude": 73.881693,
        "open_now": false,
        "phone_number": "+91 8371890884"
      },
      {
        "name": "Pharmacy Place 23",
        "address": "153 Main Street, pune",
        "rating": 3.7,
        "user_ratings_total": 386,
        "priceLevel": 2,
        "types": [
          "beauty_salon",
          "hair_care",
          "spa"
        ],
        "latitude": 18.464648,
        "longitude": 73.801149,
        "open_now": true,
        "phone_number": "+91 7379588639"
      },
      {
        "name": "Pharmacy Place 24",
        "address": "548 Main Street, pune",
        "rating": 4.0,
        "user_ratings_total": 138,
        "priceLevel": 2,
        "types": [
          "beauty_salon",
          "hair_care",
          "spa"
        ],
        "latitude": 18.517319,
        "longitude": 73.765765,
        "open_now": false,
        "phone_number": "+91 8254661559"
      }
    ],
    "trends": [
      {
        "date": "2025-07-03",
        "value": 75,
        "query": "pharmacy store",
        "geo": "pune",
        "relatedQueries": [
          "pharmacy store near me",
          "best pharmacy store"
        ]
      },
      {
        "date": "2025-07-10",
        "value": 70,
        "query": "pharmacy store",
        "geo": "pune",
        "relatedQueries": [
          "pharmacy store near me",
          "best pharmacy store"
        ]
      },
      {
        "date": "2025-07-17",
        "value": 31,
        "query": "pharmacy store",
        "geo": "pune",
        "relatedQueries": [
          "pharmacy store near me",
          "best pharmacy store"
        ]
      },
      {
        "date": "2025-07-24",
        "value": 50,
        "query": "pharmacy store",
        "geo": "pune",
        "relatedQueries": [
          "pharmacy store near me",
          "best pharmacy store"
        ]
      },
      {
        "date": "2025-07-31",
        "value": 79,
        "query": "pharmacy store",
        "geo": "pune",
        "relatedQueries": [
          "pharmacy store near me",
          "best pharmacy store"
        ]
      },
      {
        "date": "2025-08-07",
        "value": 42,
        "query": "pharmacy store",
        "geo": "pune",
        "relatedQueries": [
          "pharmacy store near me",
          "best pharmacy store"
        ]
      },
      {
        "date": "2025-08-14",
        "value": 35,
        "query": "pharmacy store",
        "geo": "pune",
        "relatedQueries": [
          "pharmacy store near me",
          "best pharmacy store"
        ]
      },
      {
        "date": "2025-08-21",
        "value": 68,
        "query": "pharmacy store",
        "geo": "pune",
        "relatedQueries": [
          "pharmacy store near me",
          "best pharmacy store"
        ]
      },
      {
        "date": "2025-08-28",
        "value": 46,
        "query": "pharmacy store",
        "geo": "pune",
        "relatedQueries": [
          "pharmacy store near me",
          "best pharmacy store"
        ]
      },
      {
        "date": "2025-09-04",
        "value": 62,
        "query": "pharmacy store",
        "geo": "pune",
        "relatedQueries": [
          "pharmacy store near me",
          "best pharmacy store"
        ]
      },
      {
        "date": "2025-09-11",
        "value": 71,
        "query": "pharmacy store",
        "geo": "pune",
        "relatedQueries": [
          "pharmacy store near me",
          "best pharmacy store"
        ]
      },
      {
        "date": "2025-09-18",
        "value": 41,
        "query": "pharmacy store",
        "geo": "pune",
        "relatedQueries": [
          "pharmacy store near me",
          "best pharmacy store"
        ]
      }
    ]
  },
  "statistics": {
    "places": {
      "total_records": 24,
      "columns_available": [
        "name",
        "address",
        "rating",
        "user_ratings_total",
        "priceLevel",
        "types",
        "latitude",
        "longitude",
        "open_now",
        "phone_number"
      ],
      "missing_values": {
        "name": 0,
        "address": 0,
        "rating": 0,
        "user_ratings_total": 0,
        "priceLevel": 0,
        "types": 0,
        "latitude": 0,
        "longitude": 0,
        "open_now": 0,
        "phone_number": 0
      },
      "rating": {
        "mean": 4.15,
        "std": 0.33,
        "min": 3.6,
        "max": 4.7,
        "distribution": {
          "3.6": 1,
          "3.7": 3,
          "3.8": 1,
          "3.9": 3,
          "4.0": 2,
          "4.1": 2,
          "4.3": 4,
          "4.4": 3,
          "4.5": 3,
          "4.7": 2
        }
      },
      "price_level": {
        "1": 9,
        "2": 8,
        "3": 1,
        "4": 6
      },
      "reviews": {
        "total": 6940,
        "average_per_business": 289.17,
        "max_reviews": 498
      }
    },
    "trends": {
      "total_records": 12,
      "columns_available": [
        "date",
        "value",
        "query",
        "geo",
        "relatedQueries"
      ],
      "time_period": "2025-07-03 to 2025-09-18",
      "interest_values": {
        "mean": 55.83,
        "trend": "moderate_decline"
      },
      "keywords": {
        "total_unique": 1,
        "top_10": {
          "pharmacy store": 12
        }
      }
    }
  },
  "eda_insights": [
    "Data Quality and Completeness:",
    "Distribution patterns in ratings, prices, etc.:",
    "6:1, 3.7:3, 3.8:1, 3.9:3, 4.0:2, 4.1:2, 4.3:4, 4.4:3, 4.5:3, 4.7:2",
    "Temporal trends in search interest:",
    "Outliers and anomalies:",
    "Correlation patterns (if detectable):",
    "Market concentration indicators:"
  ],
  "key_patterns": {
    "market_maturity": "developing",
    "competition_level": "medium",
    "customer_sentiment": "positive",
    "price_sensitivity": "unknown",
    "growth_trend": "moderate_decline"
  }
}

# Convert to DataFrames for analysis
places_data = pd.DataFrame(research_data.get('places_data', []))
trends_data = pd.DataFrame(research_data.get('trends_data', []))

print("Data Overview:")
print(f"Places data: {len(places_data)} records")
print(f"Trends data: {len(trends_data)} records")

# %% [markdown]
# # Google Places Data Analysis
# ## Business Listings & Competitive Landscape

# %%
# Basic statistics for Places data
if not places_data.empty:
    print("Places Data Columns:", places_data.columns.tolist())
    print("\nBasic Info:")
    print(places_data.info())
    print("\nDescriptive Statistics:")
    print(places_data.describe())
else:
    print("No places data available")

# %%
# Rating Distribution Analysis
if 'rating' in places_data.columns and not places_data.empty:
    plt.figure(figsize=(12, 4))
    
    plt.subplot(1, 2, 1)
    places_data['rating'].hist(bins=20, alpha=0.7, edgecolor='black')
    plt.title('Distribution of Business Ratings')
    plt.xlabel('Rating')
    plt.ylabel('Frequency')
    
    plt.subplot(1, 2, 2)
    places_data['rating'].value_counts().sort_index().plot(kind='bar', alpha=0.7)
    plt.title('Rating Frequency')
    plt.xlabel('Rating')
    plt.ylabel('Count')
    
    plt.tight_layout()
    plt.show()
    
    print(f"Average Rating: {places_data['rating'].mean():.2f}")
    print(f"Rating Std Dev: {places_data['rating'].std():.2f}")
else:
    print("No rating data available")

# %%
# Price Level Analysis
if 'priceLevel' in places_data.columns and not places_data.empty:
    plt.figure(figsize=(10, 6))
    price_counts = places_data['priceLevel'].value_counts().sort_index()
    
    plt.subplot(1, 2, 1)
    price_counts.plot(kind='pie', autopct='%1.1f%%', startangle=90)
    plt.title('Price Level Distribution')
    
    plt.subplot(1, 2, 2)
    price_counts.plot(kind='bar', alpha=0.7)
    plt.title('Price Level Frequency')
    plt.xlabel('Price Level (1=Low, 4=High)')
    plt.ylabel('Count')
    
    plt.tight_layout()
    plt.show()
else:
    print("No price level data available")

# %%
# Review Analysis
if 'user_ratings_total' in places_data.columns and not places_data.empty:
    plt.figure(figsize=(10, 5))
    
    plt.subplot(1, 2, 1)
    places_data['user_ratings_total'].hist(bins=20, alpha=0.7, edgecolor='black')
    plt.title('Distribution of Review Counts')
    plt.xlabel('Number of Reviews')
    plt.ylabel('Frequency')
    
    plt.subplot(1, 2, 2)
    # Top 10 most reviewed businesses
    top_reviewed = places_data.nlargest(10, 'user_ratings_total')[['name', 'user_ratings_total', 'rating']]
    plt.barh(range(len(top_reviewed)), top_reviewed['user_ratings_total'])
    plt.yticks(range(len(top_reviewed)), top_reviewed['name'], fontsize=8)
    plt.title('Top 10 Most Reviewed Businesses')
    plt.xlabel('Number of Reviews')
    
    plt.tight_layout()
    plt.show()
    
    print(f"Total Reviews: {places_data['user_ratings_total'].sum()}")
    print(f"Average Reviews per Business: {places_data['user_ratings_total'].mean():.1f}")
else:
    print("No review data available")

# %% [markdown]
# # Google Trends Data Analysis
# ## Market Interest & Search Patterns

# %%
# Trends Over Time Analysis
if 'date' in trends_data.columns and 'value' in trends_data.columns and not trends_data.empty:
    trends_data['date'] = pd.to_datetime(trends_data['date'])
    trends_sorted = trends_data.sort_values('date')
    
    plt.figure(figsize=(12, 6))
    plt.plot(trends_sorted['date'], trends_sorted['value'], marker='o', linewidth=2)
    plt.title('Search Interest Over Time')
    plt.xlabel('Date')
    plt.ylabel('Interest Score')
    plt.xticks(rotation=45)
    plt.grid(True, alpha=0.3)
    plt.tight_layout()
    plt.show()
    
    # Calculate trend metrics
    if len(trends_sorted) > 1:
        growth = ((trends_sorted['value'].iloc[-1] - trends_sorted['value'].iloc[0]) / 
                 trends_sorted['value'].iloc[0] * 100)
        print(f"Overall Growth Rate: {growth:.2f}%")
        
        # Recent trend (last 4 points)
        if len(trends_sorted) >= 4:
            recent_growth = ((trends_sorted['value'].iloc[-1] - trends_sorted['value'].iloc[-4]) / 
                           trends_sorted['value'].iloc[-4] * 100)
            print(f"Recent Growth Rate (last 4 periods): {recent_growth:.2f}%")
else:
    print("No trends data available for time series analysis")

# %%
# Top Keywords Analysis
if 'query' in trends_data.columns and not trends_data.empty:
    top_keywords = trends_data['query'].value_counts().head(10)
    
    if not top_keywords.empty:
        plt.figure(figsize=(10, 6))
        top_keywords.plot(kind='barh', alpha=0.7)
        plt.title('Top 10 Trending Keywords')
        plt.xlabel('Frequency')
        plt.gca().invert_yaxis()
        plt.tight_layout()
        plt.show()
    else:
        print("No keyword data available")
else:
    print("No query data available")

# %%
# Trends Summary Statistics
if not trends_data.empty:
    print("Trends Data Summary:")
    print(f"Total data points: {len(trends_data)}")
    print(f"Time period: {trends_data['date'].min()} to {trends_data['date'].max()}" if 'date' in trends_data.columns else "No date information")
    
    if 'value' in trends_data.columns:
        print(f"Average interest score: {trends_data['value'].mean():.2f}")
        print(f"Maximum interest score: {trends_data['value'].max()}")
        print(f"Minimum interest score: {trends_data['value'].min()}")
else:
    print("No trends data available for summary")

# %% [markdown]
# # AI-Generated Insights
#
# The following insights were generated by the EDA Agent based on the data analysis:

# %% [markdown]
# ## Insight 1
# Okay, the user is asking me to act as a business strategist and provide actionable insights for a pharmacy store in Pune based on specific market patterns.

# %% [markdown]
# ## Insight 2
# Let me break this down carefully.

# %% [markdown]
# ## Insight 3
# First, I need to understand the market patterns provided:
# - Market maturity: developing (so it's not saturated yet)
# - Competition level: medium (meaning there are competitors but not overwhelming)
# - Customer sentiment: positive (good sign for the market)
# - Price sensitivity: unknown (this is tricky - I'll need to address this gap)
# - Growth trend: moderate decline (concerning, but "moderate" suggests it's not collapsing)
#
# The user wants 5-7 strategic insights covering seven specific areas: market entry, pricing, customer acquisition, growth opportunities, risks, competitive advantages, and success factors.

# %% [markdown]
# ## Insight 4
# They emphasized "specific, actionable, and data-driven" - so no vague fluff.

# %% [markdown]
# ## Insight 5
# Pune is a major Indian city with interesting dynamics.

# %% [markdown]
# ## Insight 6
# I recall it has a large student population, IT professionals, and aging residents - all relevant for pharmacy needs.

# %% [markdown]
# ## Insight 7
# The "moderate decline" in growth trend is puzzling though.
